# %% [markdown]
# Name: Gaoxian Song

# %% [markdown]
# # MTH9879 Homework 2
#
# Assigned: February 7, 2017.
# Due: February 21, 2017 by 6pm.
#
# Late homework **will not be accepted**.
#
# $$
# \newcommand{\supp}{\mathrm{supp}}
# \newcommand{\E}{\mathbb{E} }
# \def\Cov{{ \mbox{Cov} }}
# \def\Var{{ \mbox{Var} }}
# \newcommand{\1}{\mathbf{1} }
# \newcommand{\PP}{\mathbb{P} }
# %\newcommand{\Pr}{\mathrm{Pr} }
# \newcommand{\QQ}{\mathbb{Q} }
# \newcommand{\RR}{\mathbb{R} }
# \newcommand{\DD}{\mathbb{D} }
# \newcommand{\HH}{\mathbb{H} }
# \newcommand{\spn}{\mathrm{span} }
# \newcommand{\cov}{\mathrm{cov} }
# \newcommand{\sgn}{\mathrm{sgn} }
# \newcommand{\HS}{\mathcal{L}_{\mathrm{HS}} }
# %\newcommand{\HS}{\mathrm{HS} }
# \newcommand{\trace}{\mathrm{trace} }
# \newcommand{\LL}{\mathcal{L} }
# %\newcommand{\LL}{\mathrm{L} }
# \newcommand{\s}{\mathcal{S} }
# \newcommand{\ee}{\mathcal{E} }
# \newcommand{\ff}{\mathcal{F} }
# \newcommand{\hh}{\mathcal{H} }
# \newcommand{\bb}{\mathcal{B} }
# \newcommand{\dd}{\mathcal{D} }
# \newcommand{\g}{\mathcal{G} }
# \newcommand{\p}{\partial}
# \newcommand{\half}{\frac{1}{2} }
# \newcommand{\T}{\mathcal{T} }
# \newcommand{\bi}{\begin{itemize}}
# \newcommand{\ei}{\end{itemize}}
# \newcommand{\beq}{\begin{equation}}
# \newcommand{\eeq}{\end{equation}}
# \newcommand{\beas}{\begin{eqnarray*}}
# \newcommand{\eeas}{\end{eqnarray*}}
# \newcommand{\cO}{\mathcal{O}}
# \newcommand{\cF}{\mathcal{F}}
# \newcommand{\cL}{\mathcal{L}}
# \newcommand{\BS}{\text{BS}}
# $$

# %% [markdown]
# <font color = "red">Homework is to be done by each student individually.  To receive full credit, you must email a completed copy of this iPython notebook to Victor Istratov (stavka@gmail.com), Yassine Ghalem (yassine.ghalem@gmail.com) and Jim Gatheral (jim.gatheral@gmail.com) by the due date and time.  All R-code must run correctly and solutions must be written up neatly in Markdown/LaTeX format.

# %% [markdown]
# ### 0. (0 points)
#
# Read Chapter 12 of Hasbrouck and Section 6.4 of Foucault, Pagano and R&ouml;ell.

# %% [markdown]
# ## The Parlour (1998) model

# %% [markdown]
# ### 1. (10 points)
# Consider the first step $t = 1$ of the 3-step order book case presented in the lecture slides. Suppose that the order book at (or just before) $t = 1$ has one share offered and one share bid ($n_B = n_A = 1$).
#
# Give the probabilities as of a market buy, market sell, limit buy and limit sell at $t = 1$,
# You may use my Mathematica notebook *Parlour.nb* as a guide (if you wish).

# %% [markdown]
# 1) At t=3, limit orders are impossible to be executed, so P(LB)=P(LS)=0 with t=3;
# $\Delta$U(MS)=B-$\beta$V=5-5.5$\beta$, P(MS|S)=P($\Delta$U(MS)>0)=$\frac{5}{11}$, by symmetry P(MB|B)=$\frac{5}{11}$,
#
# so at t=3, P(MB)=P(MS)=$\frac{5}{22}$
#
# 2) At t=2, consider the case of seller:
#
# if the case is not ($n_B=1$,$n_A=0$), P(LS|S)=0 as there is no probability of limit sell order execution; so P(MS)=$\frac{5}{22}$;
#
# if the case is ($n_B=1$,$n_A=0$), $\Delta$U(MS)=5-5.5$\beta$, $\Delta$U(LS)=P(MB at t=3)$\times$(6-5.5$\beta$),
#
# P(MS|S)=P($\Delta$U(MS)>0 and $\Delta$U(MS)>$\Delta$U(LS))=P($\beta$<$\frac{160}{187}$)=$\frac{80}{187}$,
#
# P(LS|S)=P($\Delta$U(MS)<$\Delta$U(LS) and $\Delta$U(LS)>0)=$\frac{2}{17}$;
#
# so P(MS)=$\frac{40}{187}$ and P(LS)=$\frac{1}{17}
#
# Denote the probability of case ($n_B=1$, $n_A=0$) by p,
# $$P(MS)=(1-p)\times \frac{5}{22}+p\times \frac{40}{187}$$
# $$P(LS)=p\times \frac{1}{17}$$
# By symmetry, P(MB)=P(MS) and P(LB)=P(LS)
#
# 3) At t=1, note that p=P(MB)=P(MS), consider the case of seller:
#
# $$\Delta U(MS)=5-5.5\beta$$ $$\Delta U(LS)=(6-5.5\beta)P(MB_2)\times P(MB_3)$$
# Thus, $$P(MS|S)=2p=P(\Delta U(MS)>\Delta U(LS) and \Delta U(MS)>0)$$
# Then here is the equation I get:
# $$\frac{25}{374}p^2+\frac{85758}{4114}p-\frac{1135}{242}=0$$
# Solve and get p=P(MB)=P(MS)=0.2248315 and P($MB_2$)=P(MB at t=2)=0.224267 and P($MB_3$)=$\frac{5}{22}$
#
# Thus, $$P(LS|S)=P(\Delta U(LS)>\Delta U(MS) and \Delta U(LS)>0)$$
# $$P(LS|S)=P(0.899326<\beta <\frac{12}{11})=0.0957916$$
# So P(LS)=P(LB)=0.5$\times$P(LS|S)=0.047896

# %% [markdown]
# In conclusion: at t=1, P(MS)=P(MB)=0.2248315, P(LS)=P(LB)=0.047896

# %% [markdown]
# ### 2. (4 points)
# Explain why the optimal market/limit order decision depends in general on quantity available on both sides of the order book in the Parlour model.

# %% [markdown]
# One assumption in Parlour model is that if the limit order has 0 probability to be executed, limit order will not be submited. So if the quantity available on both sides is very large, the probability of executing a limit order (placed at the end of waiting queue) is very low and the expected waiting time for execution is long requiring $\beta$ to be very high. So if queue size is large, it will be more likely to submit a market order than a limit order

# %% [markdown]
# ### Set up R-environment

# %%
#R version is 3.3.2
download.file(url="http://mfe.baruch.cuny.edu/wp-content/uploads/2015/01/ziSetup.zip", destfile="ziSetup.zip")
unzip(zipfile="ziSetup.zip")
source("ziSetup.R")
library(repr)
options(repr.plot.height=5)

# %% [markdown]
# ## Cont-Kukanov optimal order placement

# %% [markdown]
# ### 3. (16 points)
#
# Consider the two BATS exchanges BZX and BYX.  Suppose you are trying to buy shares of MSFT in 3.9 minutes ($1\%$ of the trading day).  Suppose further that the two exchanges have the following characteristics:
#
# **Exchange** | **Make fee** | **Take fee** | **Daily volume**
# -----|-----:|-------:| ---- |
# | **(per share)** | **(per share)** | **(shares)**
# BZX | -0.32¢ | +0.30¢ | 10,500,000
# BYX | +0.03¢ | -0.03¢ | 1,300,000
#
# Assume the daily volatility of MSFT is $1\%$ and that MSFT is trading at $\$37.50$.
#
# (a) We may suppose that if your order is only partially filled, that's because the price moved away (*adverse selection*).  This suggests that we penalize any under fill of limit orders by $\sigma\,\sqrt{T}$ where $T$ is the order duration.  Compute the corresponding value of $\lambda_u$ in cents per share.
#
# Answer: $$\lambda_u = 37.5\times \sigma \sqrt{T} =37.5\times 1\% \times \sqrt{1\%} =37.5\times 0.01\times 0.1=0.001\times37.5=3.75(cents/share)$$
#
#
# (b) Assuming a spread of $1$ cent, what are $h$, $f$, and $r$ for BZX and BYX respectively (in cents per share)?
#
# Answer:
#
# For BZX: $$h=0.5(cent/share)$$ $$f=0.3(cent/share)$$ $$r=0.32(cent/share)$$
#
# For BYX: $$h=0.5(cent/share)$$ $$f=-0.03(cent/share)$$ $$r=-0.03(cent/share)$$
#
#
# (c) Assuming no seasonality, what is the mean value $\bar \xi$ of $\xi$ (over 3.9 minutes) for BZX and BYX respectively (in shares)?
#
# Answer:
#
# For BZX: $$\bar \xi=1\% \times 10500000=105000(share)$$
#
# For BYX: $$\bar \xi=1\% \times 1300000=13000(share)$$
#
#
# (d)  Assume that $\xi$ is log normally distributed with
#
# $$
# \xi = \bar \xi \,\exp\left\{\sigma\,Z-\frac 12\,\sigma^2\right\}.
# $$
#
# where $Z \sim N(0,1)$ and $\sigma = 1/2$.  What is the standard deviation of $\xi$ (in terms of $\bar \xi$)?
#
# Answer: $$E(\xi^2)=\bar \xi^2 \int_R exp(2\sigma Z-\sigma^2)\times\frac{1}{\sqrt{2\pi}}exp(-\frac{z^2}{2})dz$$
# $$E(\xi^2)=\bar \xi^2 \int_R \frac{1}{\sqrt{2\pi}}exp(-\frac{(z-2\sigma)^2}{2})exp(\sigma^2)dz
#           =\bar \xi^2 exp(\sigma^2)$$
# $$std(\xi)=\bar \xi \sqrt{exp(\sigma^2)-1}=\bar \xi \sqrt{exp(0.25)-1}$$
#
#
# (e) Write R-code to determine the optimal order size $L^\star+Q$ on BZX and BYX respectively. Assume here that you will either trade on BZX or BYX; there is no splitting of the order between the two exchanges. <br>
# (Hint: You may find the R function *qnorm(. )* useful).
#
# Prep: $$P(\xi \leq x)=P(\bar \xi exp(\sigma Z-0.5\times \sigma^2)\leq x)=P(Z\leq \frac{\sigma}{2} +\frac{1}{\sigma}ln(\frac{x}{\bar \xi})) $$
#
#
# (f) Compare the optimal limit order sizes from part (e) with the ratios of quote sizes and volumes on BZX and BYX.  Are your results from part (e) roughly consistent with observation.  You may assume that the quote sizes shown on the MSFT BATS slides from Lecture 1 are typical.

# %%
#e)
GetLQ<-function(h,f,r,lambda,sigma,xibar){
    prob<-(2*h+f-r)/(h+r+lambda)
    inv<-qnorm(prob)
    temp1<-inv-0.5*sigma
    temp1<-temp1*sigma
    x<-exp(temp1)*xibar
}
LQ_BZX<-GetLQ(0.5,0.3,0.32,3.75,0.01,105000)
LQ_BYX<-GetLQ(0.5,-0.03,-0.03,3.75,0.01,13000)
print(c("For BZX: L+Q is ",round(LQ_BZX)))
print(c("For BYX: L+Q is ",round(LQ_BYX)))
# Out:
# [1] "For BZX: L+Q is " "104167"
# [1] "For BYX: L+Q is " "12907"

# %%
#f)
Q_BZX<-800 #best quote size
Q_BYX<-100 #best quote size
L_BZX<- LQ_BZX-Q_BZX # L for BZX
L_BYX<- LQ_BYX-Q_BYX #L for BYX
V_BZX<-10500000 #Volume for BZX
V_BYX<-1300000 #Volume for BYX
print("ratio of L_BYX and Q_BYX:")
print(L_BYX/Q_BYX)
print("ratio of L_BZX and Q_BZX:")
print(L_BZX/Q_BZX)
print("ratio of L_BYX and volume_BYX:")
print(L_BYX/V_BYX)
print("ratio of L_BZX and volume_BZX:")
print(L_BZX/V_BZX)
#these ratios are consistent in pairs
# Out:
# [1] "ratio of L_BYX and Q_BYX:"
# [1] 128.066
# [1] "ratio of L_BZX and Q_BZX:"
# [1] 129.2093
# [1] "ratio of L_BYX and volume_BYX:"
# [1] 0.009851227
# [1] "ratio of L_BZX and volume_BZX:"
# [1] 0.009844515

# %% [markdown]
# ## The Bouchaud-M&eacute;zard-Potters order book approximation

# %% [markdown]
# ### 4. (16 points)
#
# When $\lambda(u)=\alpha$,  a constant, the BMP order density becomes
#
# \begin{eqnarray*}
# \rho_{BMP}(\Delta) &=& \frac{\alpha}{\delta}\,\left\{e^{-\Delta/{\tilde \Delta}}\,\int_0^{\Delta/{\tilde\Delta}}\,\sinh(u)\,du + \sinh(\Delta/{\tilde \Delta})\,\int_{\Delta/{\tilde\Delta}}^\infty\,e^{-u}\,du\right\} \\
# &=&\frac{\alpha}{\delta}\,\left\{1 - e^{-\Delta/{\tilde \Delta}}  \right\}
# \end{eqnarray*}
#
# where the characteristic distance
#
# $$
# \tilde \Delta=\sqrt{\frac{\sigma^2}{2\,\delta}}.
# $$
#
# (a) Amend the SFGK zero intelligence code from Problem 3 of HW1 to count the number of limit orders generated in addition to computing the average book shape.
#
# (b) With $\alpha = 1$, $\mu = 10$ and $\delta = \frac15$, simulate 100,000 events and plot the resulting average book shape in red (in a band $\pm 20$ around the mid price).
#
# (c) From your simulation, what is the probability $P_L$ of a limit order at a given level conditional on an event? (Recall that there are 60 limit order levels in the simulation).
#
# (d) In [Gatheral and Oomen]<sup id="cite_ref-GO" class="reference"><a href="#cite_note-GO"><span>[</span>1<span>]</span></a></sup>, with these SFGK parameters, realized variance per event was estimated as
#
# $$
# \sigma^2_{GO} = 0.083.
# $$
#
# Using your estimate $P_L$ of limit orders per level per event, convert this estimate to variance per limit order (recall that $\alpha=1$).  Denote your result by $\sigma^2_{GO}$.  Compute the characteristic distance $\tilde \Delta_{GO}$ with this estimate $\sigma^2_{GO}$.
#
# (e) In Lecture 1, using dimensional analysis, we estimated that variance $\sigma^2_{DA}$ per unit time should be of the order of
#
# $$
# \sigma^2_{DA} = \frac{\mu\,\delta}{\alpha^2}.
# $$
#
# Compute the characteristic distance $\tilde \Delta_{DA}$ with this estimate $\sigma^2_{DA}$.
#
# (f)  Using your two estimates of $\tilde \Delta$ from parts (d) and (e),  write functions to compute the corresponding order book densities $\rho_{GO}(\Delta)$ and $\rho_{DA}(\Delta)$.
#
# (g)
# Superimpose plots of the asymptotic densities $\rho_{DA}(\Delta)$ (in blue) and $\rho_{DA}(\Delta)$ (in orange) on your plot of the average book shape.

# %%
#a)
#updated code
logging<- F #set logging to F to speed up running
pos=21 #store the mid position index
alpha<- 1 #set alpha
mu<- 10 #set mu
delta<-0.2
numEvents<- 100000 #set numEvents
initializeBook5() #initialize order book
band<- 20 #set band
aveBookShape<- bookShape(band)/numEvents #initialize average book shape
countLimitBuy<- rep(0,30) #store count of limit buys
countLimitSell<- rep(0,30) #store count of limit sells
nb <<- sum(book$buySize[book$Price>=(bestOffer()-L)]); # Number of cancelable buy orders
ns <<- sum(book$sellSize[book$Price<=(bestBid()+L)]); # Number of cancelable sell orders
eventRate <- nb*delta+ns*delta + mu +2*L*alpha;
probEvent <- c(L*alpha,L*alpha,nb*delta,ns*delta,mu/2,mu/2)/eventRate;
for (i in 1:numEvents){
  m <- sample(1:6, 1, replace = TRUE, probEvent); #Choose event type
  price<-0
  level=0
  if (m==1){ #selected event is limitbuy
    level=pick(L) #set level
    price <- (bestOffer()-level) #set price
    countLimitBuy[level]<-countLimitBuy[level]+1 #increment limit buy count at this level
  }
  if(m==2){
    level=pick(L) #selected event is limit sell and set level
    price<-(bestBid()+level) #set price
    countLimitSell[level]<-countLimitSell[level]+1 #increment limit sell count at this level
  }
  switch(m,
         limitBuyOrder(price),
         limitSellOrder(price),
         cancelBuyOrder(),
         cancelSellOrder(),
         marketBuyOrder(),
         marketSellOrder()
  );
  aveBookShape<- aveBookShape+bookShape(band)/numEvents
}
#b) plot order shape
plot(-band:band,aveBookShape,main=c("average book shape"), xlab="Relative Price",ylab="Shares",col="red",type="b")
#c)
total_prob=rep(0,60)
for (i in 1:L){
    total_prob[i]=countLimitSell[i]/numEvents
    total_prob[i+30]=countLimitBuy[31-i]/numEvents
}
print(countLimitSell/numEvents)
print(countLimitBuy/numEvents)
plot(1:60,total_prob,main=c("probability of limit order at various levels"),xlab="level",ylab="probability",col="red",type="b")
# Out:
#  [1] 0.00824 0.00805 0.00769 0.00788 0.00796 0.00854 0.00840 0.00836 0.00814
# [10] 0.00865 0.00800 0.00824 0.00803 0.00810 0.00823 0.00771 0.00822 0.00827
# [19] 0.00818 0.00831 0.00830 0.00825 0.00834 0.00813 0.00853 0.00808 0.00800
# [28] 0.00805 0.00853 0.00814
#  [1] 0.00877 0.00827 0.00769 0.00813 0.00812 0.00788 0.00798 0.00828 0.00812
# [10] 0.00808 0.00861 0.00769 0.00848 0.00833 0.00831 0.00851 0.00793 0.00844
# [19] 0.00801 0.00801 0.00788 0.00853 0.00841 0.00822 0.00817 0.00840 0.00819
# [28] 0.00858 0.00835 0.00840
# Plot with title “average book shape”
# Plot with title “probability of limit order at various levels”

# %%
#d) for events of limit orders, I only consider best quotes.
freq<-countLimitSell[1]/numEvents+countLimitBuy[1]/numEvents
scale_factor<-1/freq
print(scale_factor)
# Out:
# [1] 58.78895

# %% [markdown]
# Variance per limit order=scale_factor$\times \sigma^2_{GO}$=58.78895$\sigma^2_{GO}$

# %%
sigma2_GO<-scale_factor*0.083

# %%
delta_GO<-sqrt(sigma2_GO/(2*delta))
print(delta_GO)
# Out:
# [1] 3.492665

# %% [markdown]
# $$\tilde \Delta_{GO}=\sqrt{\frac{\sigma^2_{GO}}{2\delta}}=3.492665$$

# %%
#e) 
sigma_DA2<-mu*delta/(alpha*alpha) #compute variance(DA)
delta_DA<-sqrt(sigma_DA2/(2*delta)) #compute Delta(DA)
print(delta_DA)
# Out:
# [1] 2.236068

# %% [markdown]
# $$ \tilde \Delta_{DA}=\sqrt{\frac{\sigma^2_{DA}}{2\delta}}=2.236068 $$

# %%
#f) 
rho_GO<-function(u){
    alpha/delta*(1-exp(-abs(u)/delta_GO))
}
rho_DA<-function(u){
    alpha/delta*(1-exp(-abs(u)/delta_DA))
}

# %%
#g)
#b) plot order shape
plot(-band:band,aveBookShape,main="",ylim=range(c(aveBookShape,rho_GO(-band:band),rho_DA(-band:band))), xlab="Relative Price",ylab="Shares per level",col="red",type="b")
par(new=TRUE)
#add plot of rho_GO
plot(-band:band,rho_GO(-band:band),ylim=range(c(aveBookShape,rho_GO(-band:band),rho_DA(-band:band))),col="orange",type="b",xlab="",ylab="")
par(new=TRUE)
#add plot of rho_DA
plot(-band:band,rho_DA(-band:band),ylim=range(c(aveBookShape,rho_GO(-band:band),rho_DA(-band:band))),col="blue",type="b",xlab="",ylab="")
legend("bottomleft",lty=c(3,3,3),legend=c("ZI","GO","DA"),col=c("red","orange","blue"))
# Out:
# Plot with title “”

# %% [markdown]
# ### 5. (6 points)
#
# Another of Mike and Farmer's observations is that the distribution of marketable as well as unmarketable limit orders as a function of distance $\Delta$ to the same-side best quote is well-described by a Student-$t$ distribution.  Assume $\mu=1/2$ as above.
#
# (a) Derive an expression in terms of the Student-$t$ cumulative density function for the ratio of arrival rates of limit to market orders as a function of the spread $s$.  How does this ratio vary with $s$?
#
# Answer: Let F(u) be cdf of Student-t distribution and assume that P(seller)=0.5=P(buyer).
# $$P(LB)=0.5\times F(\frac{s}{2})$$
# $$P(LS)=P(LB)$$
# $$P(MB)=(1-F(\frac{s}{2}))\times 0.5$$
# $$P(MS)=P(MB)$$
# Thus, $$Limit/Market=F(\frac{s}{2})/(1-F(\frac{s}{2}))$$
# According to the plot below, the larger the spread, it is more likely to come a limit order than a market order.
#
# (b) Relative to the zero-intelligence model, does this empirically observed strategic behavior make the spread revert faster or more slowly?
#
# Answer: In ZI model, arrival of limit and market orders does not vary with spread. But with this observed behavior, when spread is larger, limit order arrives more frequently than market order. Limit order can narrow the spread and market order can widen the spread. So such behavior makes the spread revert faster.

# %%
#plot for a)
s<-seq(0.01,0.5,0.01)
mu<-0.5
plot(s,pt(s/2,mu)/(1-pt(s/2,mu)),xlab="spread",ylab="Limit/Market",type="l")
# Out:
# plot without title

# %% [markdown]
# ### References
#
# <div class="reflist" style="list-style-type: decimal;">
#
# <ol>
#
#   <li id="cite_note-GO"><span class="mw-cite-backlink"><b><a href="#cite_ref-GO">^</a></b></span> Jim Gatheral and Roel C. A Oomen, Zero-intelligence realized variance estimation, <span>*Finance and Stochastics*,</span> <span>**14**</span>(2) 249–283, 2010.</li>
#
# </ol>
